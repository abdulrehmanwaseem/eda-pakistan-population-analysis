# %% [markdown]
# # **PAKISTAN Population Analysis**

# %% [markdown]
# **Author Name:** Abdul Rehman \
# **Email:** abdulrehmanwork2024@gmail.com \
# **Website:** [abdulrehamn-code](https://abdulrehman-code.vercel.app)\
# **Dateset Source:** [link](https://www.kaggle.com/datasets/mabdullahsajid/population-of-pakistan-dataset)\
# **Year of Data:** 2017 & 1998

# %% [markdown]
# ## 📊 Pakistan Population Census 2017 – Dataset Description
#
# ### **Overview**
# This dataset contains demographic information from the **Pakistan Population Census 2017**.
# It provides detailed population data at various administrative levels within Pakistan, including **provinces, divisions, districts, and sub-divisions**.
#
# The dataset also includes insights into **urban/rural populations, gender distribution, transgender individuals, sex ratios, historical comparisons (1998), and annual growth rates**.
#
# ---
#
# ### **Features**
#
# - **Province**: Administrative provinces/regions of Pakistan where the census data was collected.
# - **Division**: The divisions within each province (2nd-level administrative units).
# - **District**: Districts within each division (larger administrative units).
# - **Sub-Division**: Sub-divisions/tehsils within each district (localized level).
# - **Area (sq. km)**: Land area of each sub-division.
# - **Urban Population (2017)**: Population living in urban areas.
# - **Rural Population (2017)**: Population living in rural areas.
# - **Male Population (2017)**: Male population count.
# - **Female Population (2017)**: Female population count.
# - **Transgender Population (2017)**: Transgender population count.
# - **Sex Ratio (2017)**: Number of females per 1000 males.
# - **Population (1998)**: Population count from the 1998 census.
# - **Annual Growth Rate (%)**: Annual population growth rate between 1998–2017.

# %% [markdown]
# ## Purpose of this analysis:
# we will fill this at the end or during the process

# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the dataset
df = pd.read_csv('./data/sub-division_population_of_pakistan.csv')

# %% [markdown]
# # 1. Compoisiton

# %%
# Explore the data (Composition)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
# max column printing option enable
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
# Let's see all columns names at once
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
# Let's have a look at data types
df.dtypes
# Out:
# PROVINCE                       object
# DIVISION                       object
# DISTRICT                       object
# SUB DIVISION                   object
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# TRANSGENDER (RURAL)             int64
# SEX RATIO (RURAL)             float64
# AVG HOUSEHOLD SIZE (RURAL)    float64
# POPULATION 1998 (RURAL)         int64
# ANNUAL GROWTH RATE (RURAL)    float64
# ALL SEXES (URBAN)               int64
# MALE (URBAN)                    int64
# FEMALE (URBAN)                  int64
# TRANSGENDER (URBAN)             int64
# SEX RATIO (URBAN)             float64
# AVG HOUSEHOLD SIZE (URBAN)    float64
# POPULATION 1998 (URBAN)         int64
# ANNUAL GROWTH RATE (URBAN)    float64
# dtype: object

# %%
# Summary statistics
df.describe().T
# Out:
#                             count           mean            std  min  \
# AREA (sq.km)                528.0    1492.005871    2039.453778  0.0
# ALL SEXES (RURAL)           528.0  246278.011364  271189.816559  0.0
# MALE (RURAL)                528.0  125275.687500  137563.021458  0.0
# FEMALE (RURAL)              528.0  120984.149621  133716.898296  0.0
# TRANSGENDER (RURAL)         528.0      18.174242      25.522248  0.0
# SEX RATIO (RURAL)           528.0      98.982614      26.812660  0.0
# AVG HOUSEHOLD SIZE (RURAL)  528.0       6.277064       2.074947  0.0
# POPULATION 1998 (RURAL)     528.0  167427.994318  178388.976993  0.0
# ANNUAL GROWTH RATE (RURAL)  528.0       3.124792       9.577872  0.0
# ALL SEXES (URBAN)           528.0  140863.528409  351246.279136  0.0
# MALE (URBAN)                528.0   72843.386364  182349.241379  0.0
# FEMALE (URBAN)              528.0   67997.865530  168872.528212  0.0
# TRANSGENDER (URBAN)         528.0      22.276515      66.068127  0.0
# ...

# %%
# How many are the missing values?
df.isnull().sum()
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %%
# Box plot on the basis of area column
sns.boxplot(data=df, y='AREA (sq.km)',)
# Out:
# <Axes: ylabel='AREA (sq.km)'>

# %%
sns.histplot(data=df, x='AREA (sq.km)',)
# Out:
# <Axes: xlabel='AREA (sq.km)', ylabel='Count'>

# %%
sns.boxplot(data=df, y='ALL SEXES (RURAL)', x="DIVISION")
# Out:
# <Axes: xlabel='DIVISION', ylabel='ALL SEXES (RURAL)'>

# %%
# It is very hard to plot, therefore, we will use groupby function to make tabular representation
df["DIVISION"].nunique()
# Out:
# 28

# %%
df.groupby("DIVISION").size().sort_values()
# Out:
# DIVISION
# Badin Division                   5
# MARDAN DIVISION                  7
# SAHIWAL DIVISION                 7
# KOHAT DIVISION                  14
# MULTAN DIVISION                 14
# D.G.KHAN DIVISION               14
# DERA ISMAIL KHAN DIVISION       15
# HAZARA DIVISION                 15
# BANNU DIVISION                  15
# Shaheed Benazirabad Division    15
# BAHAWALPUR DIVISION             15
# LAHORE DIVISION                 17
# SARGODHA DIVISION               17
# FAISALABAD DIVISION             17
# Kalat Division                  18
# PESHAWAR DIVISION               18
# Mirpurkhas Division             18
# Sukkur Division                 18
# Zhob Division                   19
# Naseerabad Division             19
# GUJRANWALA DIVISION             20
# Larkana Division                21
# RAWALPINDI DIVISION             22
# Hyderabad Division              30
# Karachi Division                30
# MALAKAND DIVISION               33
# ...

# %%
pd.set_option('display.max_rows', None)
df.groupby(["PROVINCE",  "DIVISION", "DISTRICT","SUB DIVISION"])["ALL SEXES (RURAL)"].mean()
# Out:
# PROVINCE     DIVISION                      DISTRICT                      SUB DIVISION
# BALOCHISTAN  Kalat Division                KALAT DISTRICT                GAZG SUB-TEHSIL                   5721.0
#                                                                          JOHAN SUB-TEHSIL                 10708.0
#                                                                          KALAT TEHSIL                     92298.0
#                                                                          MANGOCHAR TEHSIL                 65678.0
#                                                                          SURAB TEHSIL                    165260.0
#                                            KHUZDAR DISTRICT              ARANJI SUB-TEHSIL                42318.0
#                                                                          KARAKH SUB-TEHSIL                31016.0
# ...

# %%
pop_rural_2017 = df["ALL SEXES (RURAL)"].sum()
pop_rural_1998 = df["POPULATION 1998 (RURAL)"].sum()

# %%
print("The total rural population in 1998 was:", pop_rural_1998)
print("The total rural population in 2017 was:", pop_rural_2017)
# Out:
# The total rural population in 1998 was: 88401981
# The total rural population in 2017 was: 130034790

# %%
# How much rural population has changed from 1998 to 2017?
rural_change = pop_rural_2017 - pop_rural_1998
if rural_change > 0:
    print("The rural population increased by:", rural_change)
    print(f"The rural population increased in percentage: {round(rural_change / pop_rural_1998 * 100, 2)}%")
else:
    print("The rural population decreased by:", abs(rural_change))
    print(f"The rural population decreased in percentage: {round(abs(rural_change) / pop_rural_1998 * 100, 2)}%")
# Out:
# The rural population increased by: 41632809
# The rural population increased in percentage: 47.09%

# %%
pop_urban_2017 = df["ALL SEXES (URBAN)"].sum()
pop_urban_1998 = df["POPULATION 1998 (URBAN)"].sum()

# How much urban population has changed from 1998 to 2017?
urban_change = pop_urban_2017 - pop_urban_1998
if urban_change > 0:
    print("The urban population increased by:", urban_change)
    print(f"The urban population increased in percentage: {round(urban_change / pop_urban_1998 * 100, 2)}%")
else:
    print("The urban population decreased by:", abs(urban_change))
    print(f"The urban population decreased in percentage: {round(abs(urban_change) / pop_urban_1998 * 100, 2)}%")
# Out:
# The urban population increased by: 32059612
# The urban population increased in percentage: 75.76%

# %%
print("The difference btw urban and rural population is:", abs(urban_change - rural_change))
# Out:
# The difference btw urban and rural population is: 9573197

# %%
sns.barplot(x=["Rural Population Change", "Urban Population Change"], y=[rural_change, urban_change])
# Out:
# <Axes: >

# %%
# solve this problem using aggregation and concatenation
# Assignment: How to combine 3 columns in one column? make a separate data of everything based on Sex (Male, Female and Transgender?) 
# using aggregate and concat
df['combined'] = df['MALE (URBAN)'].astype(str) + ' ' + df['FEMALE (URBAN)'].astype(str) + ' ' + df['TRANSGENDER (URBAN)'].astype(str)
df_grouped = df.groupby('ALL SEXES (URBAN)')['combined'].agg(lambda x: ' '.join(x)).reset_index()
df_grouped

# %%
df_melted = df.melt( value_vars=["MALE (RURAL)", "FEMALE (RURAL)", "TRANSGENDER (RURAL)"], var_name="sexrural", value_name="population in 1998" )[["sexrural", "population in 1998"]]
print(df_melted)
# Out:
#                  sexrural  population in 1998
# 0            MALE (RURAL)              316864
# 1            MALE (RURAL)              273788
# 2            MALE (RURAL)              182655
# 3            MALE (RURAL)              192278
# 4            MALE (RURAL)              231506
# 5            MALE (RURAL)              461525
# 6            MALE (RURAL)                   0
# 7            MALE (RURAL)              239541
# 8            MALE (RURAL)              171117
# 9            MALE (RURAL)              112952
# 10           MALE (RURAL)              288761
# 11           MALE (RURAL)              382228
# 12           MALE (RURAL)              500742
# 13           MALE (RURAL)              536887
# 14           MALE (RURAL)              516640
# 15           MALE (RURAL)              109429
# 16           MALE (RURAL)              410429
# 17           MALE (RURAL)              353638
# 18           MALE (RURAL)              300077
# ...
